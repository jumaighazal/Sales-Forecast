# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
sns.set(style='darkgrid')

# %%
train_data = pd.read_csv('data/train.csv')
test_data = pd.read_csv('data/test.csv')
item_categories = pd.read_csv('data/item_categories.csv')
items = pd.read_csv('data/items.csv')
shops = pd.read_csv('data/shops.csv')

# %%
train_data.head(5)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
shops.head(5)
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
items.head(5)
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
item_categories.head(5)
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
test_data.head(10)
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268
# 5   5        5     5039
# 6   6        5     5041
# 7   7        5     5046
# 8   8        5     5319
# 9   9        5     5003

# %%
train_data.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
train_data.isnull().values.any()
# Out:
# False

# %%
len(train_data)
# Out:
# 2935849

# %%
len(train_data['shop_id'].unique()
# Out:
# 60

# %%
len(train_data['item_id'].unique())
# Out:
# 21807

# %%
len(item_categories['item_category_name'].unique())
# Out:
# 84

# %%
len(items['item_name'].unique())
# Out:
# 22170

# %%
len(shops['shop_name'].unique())
# Out:
# 60

# %% [markdown]
# Making a copy of the DF

# %%
df = train_data.copy()

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
train_data.shape
# Out:
# (2935849, 6)

# %% [markdown]
# JOINING DATA SETS

# %%
train_data = train_data.join(items, on='item_id', rsuffix='_').join(shops, on='shop_id', rsuffix='_').join(item_categories, on='item_category_id', rsuffix='_').drop(['item_id_', 'shop_id_', 'item_category_id_'], axis=1)

# %% [markdown]
# NEW DATA

# %%
print('train_data rows: ', train_data.shape[0])
print('train_data columns: ', train_data.shape[1])
# Out:
# train_data rows:  2935849
# train_data columns:  10

# %%
train_data.head(5)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0
#
#                                   item_name  item_category_id  \
# 0                         ЯВЛЕНИЕ 2012 (BD)                37
# 1  DEEP PURPLE  The House Of Blue Light  LP                58
# 2  DEEP PURPLE  The House Of Blue Light  LP                58
# 3  DEEP PURPLE  Who Do You Think We Are  LP                58
# 4   DEEP PURPLE 30 Very Best Of 2CD (Фирм.)                56
#
#                 shop_name                   item_category_name
# 0  Ярославль ТЦ "Альтаир"                       Кино - Blu-Ray
# ...

# %% [markdown]
# check the numbers of the categories after merging.

# %%
train_data.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03
#
#        item_category_id
# count      2.935849e+06
# mean       4.000138e+01
# std        1.710076e+01
# min        0.000000e+00
# 25%        2.800000e+01
# 50%        4.000000e+01
# 75%        5.500000e+01
# max        8.300000e+01

# %%
train_data['date'].min()
# Out:
# '01.01.2013'

# %%
train_data['date'].max()
# Out:
# '31.12.2014'

# %% [markdown]
# DATA LEAKAGES
# USING 'SHOP_ID & ITEM_ID THAT APPEAR ON THE TEST SET

# %%
test_shop_ids = test_data['shop_id'].unique()
test_item_ids = test_data['item_id'].unique()
#Only shops that exist in the test set
lk_train = train_data[train_data['shop_id'].isin(test_shop_ids)]
#Only items that exist in the test set
lk_train_data = lk_train[lk_train['item_id'].isin(test_item_ids)]

# %%
print('Data set size before leaking:', train_data.shape[0])
print('Data set size after leaking:', lk_train_data.shape[0])
# Out:
# Data set size before leaking: 2935849
# Data set size after leaking: 1224439

# %% [markdown]
# DATA CLEANING (recording only item_price > 0)

# %%
train_data = train_data.query('item_price > 0')

# %% [markdown]
# Preprosessing Data
# Dropping text feautures since i'm not doing anything with it Since i'm predicting the sales for every product in the next month and our data is given by day, i'm going to remove unwanted columns and aggrgate data by month.

# %%
#Useful features
train_data = lk_train_data[['date', 'date_block_num', 'shop_id', 'item_category_id', 'item_id', 'item_price', 'item_cnt_day']]

# %%
train_data.head()
# Out:
#           date  date_block_num  shop_id  item_category_id  item_id  \
# 0   02.01.2013               0       59                37    22154
# 10  03.01.2013               0       25                55     2574
# 11  05.01.2013               0       25                55     2574
# 12  07.01.2013               0       25                55     2574
# 13  08.01.2013               0       25                55     2574
#
#     item_price  item_cnt_day
# 0        999.0           1.0
# 10       399.0           2.0
# 11       399.0           1.0
# 12       399.0           1.0
# 13       399.0           2.0

# %% [markdown]
# Adding date features

# %%
train_data['date'] = pd.to_datetime(train_data['date'], format='%d.%m.%Y')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_data['month'] = train_data['date'].dt.month
train_data['day'] = train_data['date'].dt.day
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_data['revenue'] = train_data.item_price * train_data.item_cnt_day

# %%
#Average Item price
item_price = train_data[['item_id', 'item_price']].groupby('item_id')['item_price'].mean()

item_price = item_price.reset_index()
item_price = item_price.rename(columns={'item_price': 'avg_item_price'})

item_price.head(5)
# Out:
#    item_id  avg_item_price
# 0        0            58.0
# 1        1          4490.0
# 2        2            58.0
# 3        3            79.0
# 4        4            58.0

# %%
#On average no item has a negative price
(item_price.avg_item_price < 0).sum()
# Out:
# 0

# %% [markdown]
# Monthly trend

# %%
df = train_data[['date_block_num', 'item_id']].groupby(by='date_block_num', as_index=False).nunique()

fig, ax = plt.subplots(figsize=(16,4))
plt.plot(df.item_id, sns.xkcd_rgb["denim blue"], lw=4)
plt.title("Count of Unique items sold")

df = train_data[['date_block_num', "item_cnt_day"]].groupby(by='date_block_num', as_index=False).sum()

f, ax = plt.subplots(figsize=(16, 4))
plt.plot(df.item_cnt_day, sns.xkcd_rgb["denim blue"], lw=4)
plt.title("Sum of items sold")

df = train_data[['date_block_num', 'revenue']].groupby(by='date_block_num', as_index=False).sum()

f, ax = plt.subplots(figsize=(16, 4))
plt.plot(df.revenue, sns.xkcd_rgb["denim blue"], lw=4)
plt.title("Total revenue generated")
# Out:
# Text(0.5,1,'Total revenue generated')

# %% [markdown]
# Number of Unique Items and Total Units Sold are decreasing with time.
#
# Revenue trend looks relatively flat

# %% [markdown]
# Plotting same metrics for each shop

# %%
shops_data = train_data.pivot_table(index='date_block_num', columns='shop_id', values='items_id', aggfunc='nunique', fill_value=0)

fig, ax = plt.subplots(figsize=(16,4))
cmap = sns.cubehelix_palette(8, as_cmap=True, dark=0, light=1, gamma=0.8, reverse=True)
plt.title("Count of Unique items sold")
_ = sns.heatmap(shops_data, ax=ax, cmap=cmap, cbar=False, xticklabels=False)

shops_data = train_data.pivot_table(index='date_block_num', columns='shop_id', values='items_cnt_day, aggfunc='sum', fillvalue=0)

fig, ax = plt.subplots(figsize=(16,4))
cmap = sns.cubehelix_palette(8, as_cmap=True, dark=0, light=1, gamma=0.8, reverse=True)
plt.title("Sum of items sold")
_ = sns.heatmap(shops_data, ax=ax, cmap=cmap, cbar=False, xticklabels=False)
# Out:
#   File "<ipython-input-65-ea188b2049ce>", line 8
#     shops_data = train_data.pivot_table(index='date_block_num', columns='shop_id', values='items_cnt_day, aggfunc='sum', fillvalue=0)
#                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x='date_block_num', data=train_data)

# %% [markdown]
# There are more entries for December of 2013 and 2014

# %% [markdown]
# Shop

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x='shop_id', data=train_data)

# %% [markdown]
# Shop 31 has maximum number of enteries

# %% [markdown]
# Item Category

# %%
plt.figure(figsize=(30, 10))
sns.countplot(x='item_category_id', data=train_data)

# %% [markdown]
# item category 40 has the highest number of enteries

# %% [markdown]
# Month-wise aggregation on Item Count

# %%
train_data_monthly = pd.DataFrame(train_data.groupby(['date_block_num'])['item_cnt_day'].sum().reset_index().sort_values('item_cnt_day'))
plt.figure(figsize=(30,10))
sns.barplot(x="date_block_num", y="item_cnt_day", data=train_data_monthly, order=train_data_monthly['date_block_num'])

# %% [markdown]
# We see that the number of items sold is peaking in December due to the holidays. Number of items sold in December 2013 is greater than December 2014

# %% [markdown]
# Month-wise aggregation on Total price

# %%
train_data_monthly_revenue = pd.DataFrame(train_data.groupby(['date_block_num'])['revenue'].sum().reset_index().sort_values('revenue'))
plt.figure(figsize=(30,10))
sns.barplot(x="date_block_num", y="revenue", data=train_data_monthly_revenue, order=train_data_monthly_revenue['date_block_num'])

# %% [markdown]
# We see that the Revenue is also peaking in Decembers due to the holidays. Revenue in December 2014 is greater than December 2013. This is contrary to the number of items sold

# %% [markdown]
# Shop-wise aggregation on Item count

# %%
train_data_shop = pd.DataFrame(train_data.groupby(['shop_id'])['item_cnt_day'].sum().reset_index().sort_values('item_cnt_day'))
plt.figure(figsize=(35,10))
sns.barplot(x="shop_id", y="item_cnt_day", data=train_data_shop, order=train_data_shop['shop_id'])

# %% [markdown]
# Shop 31 is selling highest number of items while shop 36 and shop 11 are selling very few items

# %% [markdown]
# Shop-wise aggregation on Revenue

# %%
train_data_shop_revenue = pd.DataFrame(train_data.groupby(['shop_id'])['revenue'].sum().reset_index().sort_values('revenue'))
plt.figure(figsize=(35,10))
sns.barplot(x="shop_id", y="revenue", data=train_data_shop_revenue, order=train_data_shop_revenue['shop_id'])

# %% [markdown]
# Shop 54 is the 5th highest in terms of revenue but the 3rd highest in terms of number of items sold.
#
# The graph above shows total sales by each shop and reveals the most popular shop

# %%
items_count = train_data['item_id'].value_counts()
items_count.head(5)
# Out:
# 20949    31340
# 5822      9408
# 17717     9067
# 2808      7479
# 4181      6853
# Name: item_id, dtype: int64

# %% [markdown]
# Which shop has the most items in shop

# %%
most_items_in_shops = pd.DataFrame(train_data.groupby(['shop_id'])['item_id'].count().reset_index().sort_values('shop_id'))
plt.figure(figsize=(35,10))
sns.barplot(x="shop_id", y="item_id", data=most_items_in_shops, order=most_items_in_shops['shop_id'])

# %% [markdown]
# Item Category-wise aggrgation on item count

# %%
train_data_item_category_id = pd.DataFrame(train_data.groupby(['item_category_id'])['item_cnt_day'].sum().reset_index().sort_values('item_cnt_day'))
plt.figure(figsize=(35,10))
sns.barplot(x="item_category_id", y="item_cnt_day", data=train_data_item_category_id, order=train_data_item_category_id['item_category_id'])

# %% [markdown]
# Item Category-wise aggrgation on Revenue

# %%
train_data_item_category_id = pd.DataFrame(train_data.groupby(['item_category_id'])['revenue'].sum().reset_index().sort_values('revenue'))
plt.figure(figsize=(35,10))
sns.barplot(x="item_category_id", y="revenue", data=train_data_item_category_id, order=train_data_item_category_id['item_category_id'])

# %% [markdown]
# Item Category 40 is being sold in max while item Category 19 makes max revenue

# %% [markdown]
# Which store keeps which categories

# %%
Product_categories_list = train_data.groupby(['shop_id', 'item_category_id'])['date'].count()
Product_categories_list.head()
# Out:
# shop_id  item_category_id
# 2        2                   133
#          3                   355
#          5                    16
#          6                   251
#          7                    68
# Name: date, dtype: int64

# %% [markdown]
# Which items gets sold the most under which product category

# %%
train_data['total_grossing] = train_data.item_price * train_data.item_cnt_day

# %%
a = train_data.groupby(['shop_id','item_category_id']).sum()['item_cnt_day'].reset_index()
fig, axs = plt.subplots(1,3,figsize=(25,10))
a[a.groupby(['shop_id'])['item_cnt_day'].transform(max) == a['item_cnt_day']].reset_index()['item_category_id'].plot(kind='bar',ax=axs[0],title='Best selling cates in each shop')
a[a.groupby(['shop_id'])['item_cnt_day'].transform(max) == a['item_cnt_day']].reset_index().groupby('item_category_id').count()['shop_id'].plot(kind='pie', title='Ratio of Best Selling cates in 60 shops', ax=axs[1]).set_ylabel('') 
a[a.groupby(['item_category_id'])['item_cnt_day'].transform(max) == a['item_cnt_day']].reset_index().groupby('shop_id').count()['item_category_id'].plot(kind='pie', title='Ratio of Best Selling shops in 84 shops', ax=axs[2]).set_ylabel('')
# Out:
# Text(0,0.5,'')

# %% [markdown]
# For each shop, the best selling categories varies, but there are category 4o and category 30 are having around 75% being the best category sellers in the 60 shops.
#
# For each category, the sales are different in each shops. While category 32, 55, and 25 are containing more of the best selling conditions of the category

# %% [markdown]
# Sales information/ item based

# %%
train_data.groupby(['item_id']).sum()['item_cnt_day'].plot()

# %% [markdown]
# Items sold by date

# %%
df_date = train_data \
    .groupby("date", as_index=False) \
    .aggregate({"item_cnt_day": "sum"})


plt.figure(figsize=(30, 10));
sns.lineplot(x="date", y="item_cnt_day", data=df_date);
plt.title("Items Sold by Date");
plt.xlabel("Date");
plt.ylabel("Items Sold");
plt.show()

# %% [markdown]
# Items sold by month

# %%
df_month = train_data \
    .groupby("month", as_index=False) \
    .aggregate({"item_cnt_day": "sum"})


month_order = ["January", "February", "March", "April", 
               "May", "June", "July", "August", "September", 
               "October", "November", "December"]

plt.figure(figsize=(30, 10));
sns.barplot(x="month", y="item_cnt_day", data=df_month);
plt.title("Items Sold by Month");
plt.xticks(rotation=45)
plt.xlabel("Month");
plt.ylabel("Items Sold");
plt.show()

# %% [markdown]
# Item sold by item id

# %%
df_item = train_data \
    .groupby("item_category_name", as_index=False) \
    .aggregate({"item_cnt_day": "sum"})


plt.figure(figsize=(10, 30));
sns.barplot(x="item_cnt_day", y="item_category_name", data=df_item);
plt.title("Items Sold by Item Name");
plt.xlabel("Items Sold");
plt.ylabel("Item Name");
plt.show()

# %% [markdown]
# Item sold by Store ID

# %%
df_store = train_data \
    .groupby("shop_id", as_index=False) \
    .aggregate({"item_cnt_day": "sum"})


plt.figure(figsize=(30,10));
sns.barplot(x="item_cnt_day", y="shop_id", data=df_store)
plt.title("Items Sold by Store Name");
plt.xlabel("Items Sold");
plt.ylabel("Store ID");
plt.show()

# %% [markdown]
# Now we have date (day, month, year, week, etc) as well as item_id, item_category_id, shop_id. We want to group them and look at the item_cnt_day and item_sale
#
# There is a clear weekly cycle, with more sales on Thu, Fri and Sat
#
# If we group them by month, we can clearly see that:
#
# Dec and Jan had the highest item_cnt_day.
# Dec also had the highest item_sale (likely Xmas)
# Nov had the lowest item_cnt_day but Jul had the lowes item_sale
# Also, there are a few peaks over the years, they are:
#
# End of Nov 2013, lots of revenues
# End of Dec 2013, lots of item_cnt_day, but relatively lower item_sale compared to Nov 2013
# End of Dec 2014, lots of item_cnt_day
# There are also peaks around the end of May 2014 and 2015
# We also see declines in item_cnt_day and item_sale from 2013 to 2015

# %% [markdown]
# n total, there were 3.6M items sold, with a combined revenue of \$3.39 billions.
#
# By item, the most popular were:
#
# By item_cnt_day was: item_id 20949, with 187642 units sold, generated $929K
# By item_sale was: item_id 6675, worth \$219M in revenue, with 10289 units sold
# The worst are: item 1590, 11871, 18062, 13474, 13477. Shops lost money on them
#
# By shop:
#
# shop_id 31 had the highest item_cnt_day (310777 items sold), and also the higest item_sale (\$235M)
# shop_id 36 had the lowest item_cnt_day (330), with a revenue of \$377K
# Item_category. The most popular:
#
# By item_cnt_day is item_category_id 40, with 634171 units sold, generating \$170M
# By item_sale is item_category_id 19, with 254887 units sold (\$412M)
# The worst performers are: item_category_id 51, with only 1 unit sold (\$129), item_category_id 50, with 3 units sold (\$24)

# %%
train_data_monthly.head()
# Out:
#    date_block_num  shop_id  item_category_id  item_id  item_price  \
# 0               0        2                 2     5572    10730.00
# 1               0        2                 2     5643     4775.21
# 2               0        2                 5     5583     1188.30
# 3               0        2                 6     7893     5970.00
# 4               0        2                 6     7894     1490.00
#
#    mean_item_price  item_cnt  mean_item_cnt  transactions
# 0      1532.857143       9.0       1.285714             7
# 1      2387.605000       0.0       0.000000             2
# 2       594.150000       2.0       1.000000             2
# 3      1990.000000       3.0       1.000000             3
# 4      1490.000000       1.0       1.000000             1

# %%
# All possible combinations of ['date_block_num', 'shop_id', 'item_id'] so there wont be any missing records.
shop_ids = train_data_monthly['shop_id'].unique()
item_ids = train_data_monthly['item_id'].unique()
empty_df = []
for i in range(34):
    for shop in shop_ids:
        for item in item_ids:
            empty_df.append([i, shop, item])
empty_df = pd.DataFrame(empty_df, columns=['date_block_num', 'shop_id', 'item_id'])

# %%
#Merge train set with the complete set(Fill missing records with 0)
train_data_monthly = pd.merge(empty_df, train_data_monthly, on=['date_block_num', 'shop_id', 'item_id'], how='left')
train_data_monthly.fillna(0, inplace=True)

# %%
train_data_monthly.head()
# Out:
#    date_block_num  shop_id  item_id  item_category_id  item_price  \
# 0               0        2     5572               2.0    10730.00
# 1               0        2     5573               2.0     1848.00
# 2               0        2     5575               2.0     3820.02
# 3               0        2     5576               2.0     7470.00
# 4               0        2     5632               2.0     2390.00
#
#    mean_item_price  item_cnt  mean_item_cnt  transactions
# 0      1532.857143       9.0       1.285714           7.0
# 1       924.000000       2.0       1.000000           2.0
# 2       955.005000       4.0       1.000000           4.0
# 3      2490.000000       3.0       1.000000           3.0
# 4      2390.000000       1.0       1.000000           1.0

# %% [markdown]
# EXTRACTING TIME BASED FEATURES

# %% [markdown]
# EDA

# %%
#Grouping data for EDA
gp_month_mean = train_data_monthly.groupby(['month'], as_index=False)['item_cnt'].mean()
gp_month_sum = train_data_monthly.groupby(['month'], as_index=False)['item_cnt'].sum()
gp_category_mean = train_data_monthly.groupby(['item_category_id'],as_index=False)['item_cnt'].mean()
gp_category_sum = train_data_monthly.groupby(['item_category_id'], as_index=False)['item_cnt'].sum()
gp_shop_mean = train_data_monthly.groupby(['shop_id'], as_index=False)['item_cnt'].mean()
gp_shop_sum = train_data_monthly.groupby(['shop_id'], as_index=False)['item_cnt'].sum()

# %% [markdown]
# Plotting graphs to show how the sales behave along the year

# %% [markdown]
# Notice we have a trend of increase of items sales count(mean) towards the end of the year.

# %%
f, axes = plt.subplots(2, 1, figsize=(22, 10), sharex=True)
sns.barplot(x="item_category_id", y="item_cnt", data=gp_category_mean, ax=axes[0], palette="rocket").set_title("Monthly Mean")
sns.barplot(x="item_category_id", y="item_cnt", data=gp_category_sum, ax=axes[1], palette="rocket").set_title("Monthly sum")
plt.show()

# %% [markdown]
# Few of the categories seems to hold most of the sell count

# %% [markdown]
# What shop sells more?

# %%
f, axes = plt.subplots(2, 1, figsize=(22, 10), sharex=True)
sns.barplot(x="shop_id", y="item_cnt", data=gp_shop_mean, ax=axes[0], palette="rocket").set_title("Monthly Mean")
sns.barplot(x="shop_id", y="item_cnt", data=gp_shop_sum, ax=axes[1], palette="rocket").set_title("Monthly Sum")
plt.show()

# %% [markdown]
# Most of the shops have similar sell rate, but 3 of them have a much higher rate, this may be as a result of the shop size
